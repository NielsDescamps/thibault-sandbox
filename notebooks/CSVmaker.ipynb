# %%
import pandas as pd

df = pd.read_excel(
    "data/profiles/Montea Gent BTM 2.xlsx",
    sheet_name="Sheet1",          # adjust to your actual sheet name
    usecols=["dates", "off", "inj"],
    parse_dates=["dates"],
    index_col="dates"
)

print(df.head())
